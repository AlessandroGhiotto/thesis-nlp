# %% [markdown]
# ![datasets-LREC-COLING.png](attachment:datasets-LREC-COLING.png)

# %% [markdown]
# Data collected on our files:
#
# | Dataset                    | Domain      | Task                                  | Type      | Class Type | avg # words | Labels | # Train samples  | # Test samples  |
# |----------------------------|-------------|---------------------------------------|-----------|------------|-------------|--------|-----------|-----------|
# | SemEval 18 (Emoji)         | Twitter     | Emoji Prediction                      | Sentence  | multiclass | 12          | 20     | 500,000   | 49,998  |
# | SemEval 18 (Irony)         | Twitter     | Irony Detection                       | Sentence  | binary     | 12          | 2      | 2,862     | 784    |
# | SemEval 19 (HatEval)       | Twitter     | Hateval                               | Sentence  | binary     | 21          | 2      | 9,000     | 2,970   |
# | SemEval 19 (OffensEval)    | Twitter     | OffensEval                            | Sentence  | binary     | 22          | 2      | 11,916    | 860    |
# | SemEval 17 (Sentiment)     | Twitter     | Sentiment Analysis                    | Sentence  | multiclass | 19          | 3      | 45,615    | 12,284  |
# | BBC news                   | News        | Topic categorisation                  | Document  | multiclass | 380         | 5      | 1,779     | 444    |
# | Reuters                    | News        | Topic categorisation                  | Document  | multiclass | 133         | 8      | 6,800     | 2,659   |
# | AG News                    | News        | Topic categorisation                  | Document  | multiclass | 31          | 4      | 2,679     | 5,928   |
# | 20 Newsgroups              | News        | Topic categorisation                  | Document  | multiclass | 176         | 6      | 10,952    | 7,290   |
# | 20 Newsgroups              | News        | Topic categorisation                  | Document  | multiclass | 176         | 20     | 10,952    | 7,290   |
# | IMDB reviews               | Reviews     | Polarity Detection                    | Document  | binary     | 234         | 2      | 28,000    | 25,601  |
# | Ohsumed                    | Medical     | Cardiovascular disease det.           | Document  | multiclass | 173         | 23     | 10,433    | 12,733  |
# | Toxic Comments             | Wikipedia   | Toxic prediction                      | Document  | multilabel | 67          | 6 (7 in paper)| 149,706  | 63,978 |
# | EU legislation documents   | Legislation | Legal legislation concept det.        | Document  | multilabel | 33          | 10     | 937       | 158    |
# | Hallmarks of cancer        | Medical     | Hallmarks of cancer detection         | Sentence  | multilabel | 25          | 10     | 2,292     | 892    |

# %%
import pandas as pd
import os

# CHANGE WORKING DIRECTORY TO ROOT
current_dir = os.path.basename(os.getcwd())
if current_dir == "src":
    os.chdir("..") # Move up by 1
elif os.path.basename(os.getcwd()) == "bai-thesis-nlp":  
    pass # If already at root, stay there
else:
    os.chdir("../..") # Move up by 2 otherwise

from src._utils._data_analysis_helpers import basic_analysis

# %% [markdown]
# # AG News

# %%
df = pd.read_csv("real_data/train/agnewstrainAll.csv")
display(df.head())
df = df.rename(columns={"2": "text", "3": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/agnewsAll.csv")
print("Number of test samples: ", len(df))
# Out:
#             0                                                  1  \
# 0  1000_train         Hartford executive #39;s stock sale probed
# 1  1001_train                                 Cool Batman Photo!
# 2  1002_train  Stocky Monkey in Himalayas Becomes Newest Prim...
# 3  1003_train                Bush, Kerry Don''t Worry About Tech
# 4  1004_train                   The Teeming Crowd in Video Games
#
#                                                    2         3
# 0  New York AG is investigating the timing of a s...  Business
# 1  In related news, it was announced yesterday th...  Sci/Tech
# 2  Scientists from India working in the Himalayas...  Sci/Tech
# 3  Election Day is less than two weeks away, but ...  Sci/Tech
# 4  Jeffrey Griffiths, the president and chief exe...  Sci/Tech
# Number of train samples: 2679
# Set of labels: {'Sports', 'Sci/Tech', 'Business', 'World'}
# Number of labels: 4
# Missing Values:
# 0              0
# 1              0
# text           0
# ...

# %% [markdown]
# # BCC News

# %%
df = pd.read_csv("real_data/train/bbcdatatrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/bbcdataAll.csv")
print("Number of test samples: ", len(df))
# Out:
#       0                                                  1              2
# 0  1491  Jones medals 'must go if guilty'  World Anti-D...          sport
# 1  2002  Britons growing 'digitally obese'  Gadget love...           tech
# 2  1573  Wenger steps up row  Arsene Wenger has stepped...          sport
# 3  1841  Domain system scam fear  A system to make it e...           tech
# 4   611  Lopez misses UK charity premiere  Jennifer Lop...  entertainment
# Number of train samples: 1779
# Set of labels: {'business', 'sport', 'politics', 'entertainment', 'tech'}
# Number of labels: 5
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    1779.00
# mean      380.13
# std       227.44
# min        89.00
# 25%       245.00
# 50%       328.00
# 75%       468.00
# max      4432.00
# Name: text_length, dtype: float64
# Number of test samples:  444

# %% [markdown]
# # Hallmarks of cancer

# %%
df = pd.read_csv("real_data/train/cancertrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/cancerAll.csv")
print("Number of test samples: ", len(df))
# Out:
#             0                                                  1  \
# 0  20179302.6  Collectively , our findings suggest that selen...
# 1  12536240.4  NK cells and CD56(+) T cells from tumour-beari...
# 2  12536240.5  The expression of CD94 and the KIR isotypes CD...
# 3  12536240.6  Simultaneous ligation of CD158a , CD158b and K...
# 4  12536240.7  Our results suggest that , while hepatic CD56(...
#
#                                   2
# 0  ['tumor promoting inflammation']
# 1   ['avoiding immune destruction']
# 2   ['avoiding immune destruction']
# 3   ['avoiding immune destruction']
# 4   ['avoiding immune destruction']
# Number of train samples: 2292
# ...

# %% [markdown]
# # EU legislation documents

# %%
df = pd.read_csv("real_data/train/legaldatatrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/legaldataAll.csv")
print("Number of test samples: ", len(df))
# Out:
#             0                                                  1  \
# 0  32006D0450  2006/450/EC: Council Decision of  27 June 2006...
# 1  32005D0055  2005/55/EC: Commission Decision of 25 January ...
# 2  32004R1934  Regulation (EC) No 1934/2004 of the European P...
# 3  31996L0078  Commission Directive 96/78/EC of 6 December 19...
# 4  32003D1608  Decision No 1608/2003/EC of the European Parli...
#
#                          2
# 0   ['cooperation policy']
# 1            ['vegetable']
# 2   ['cooperation policy']
# 3  ['customs regulations']
# 4   ['cooperation policy']
# Number of train samples: 937
# Set of labels: {"['international trade']", "['fruit']", "['customs regulations']", "['trading operation']", "['tariff policy']", "['cooperation policy']", "['vegetable']", "['public contract']", "['market prices']", "['export policy']"}
# Number of labels: 10
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# ...

# %% [markdown]
# # 20 Newsgroups (6 labels)

# %%
df = pd.read_csv("real_data/train/newsgroups6trainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/newsgroups6All.csv")
print("Number of test samples: ", len(df))
# Out:
#             0                                                  1           2
# 0     0_train  I was wondering if anyone out there could enli...  recreation
# 1     1_train  A fair number of brave souls who upgraded thei...   computers
# 2    10_train  I have a line on a Ducati 900GTS 1978 model wi...  recreation
# 3   100_train  / hpcc01:rec.motorcycles / Stafford@Vax2.Winon...  recreation
# 4  1000_train  Heavy-duty, commercial, TINY,(6x3x1/2 inch) WA...    for sale
# Number of train samples: 10952
# Set of labels: {'science', 'politics', 'computers', 'for sale', 'recreation', 'religion'}
# Number of labels: 6
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    10952.00
# mean       175.90
# std        497.27
# min          1.00
# 25%         40.00
# 50%         80.00
# 75%        158.00
# max      11694.00
# Name: text_length, dtype: float64
# Number of test samples:  7290

# %% [markdown]
# # 20 Newsgroups (20 labels)

# %%
df = pd.read_csv("real_data/train/newsgroups20trainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/newsgroups20All.csv")
print("Number of test samples: ", len(df))
# Out:
#             0                                                  1             2
# 0     0_train  I was wondering if anyone out there could enli...         autos
# 1     1_train  A fair number of brave souls who upgraded thei...  mac hardware
# 2    10_train  I have a line on a Ducati 900GTS 1978 model wi...   motorcycles
# 3   100_train  / hpcc01:rec.motorcycles / Stafford@Vax2.Winon...   motorcycles
# 4  1000_train  Heavy-duty, commercial, TINY,(6x3x1/2 inch) WA...      for sale
# Number of train samples: 10952
# Set of labels: {'ibm hardware', 'baseball', 'autos', 'for sale', 'windows x', 'mideast', 'ms-windows', 'guns', 'medicine', 'mac hardware', 'graphics', 'atheism', 'crypt', 'motorcycles', 'christian', 'hockey', 'electronics', 'politics', 'space', 'religion'}
# Number of labels: 20
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    10952.00
# mean       175.90
# std        497.27
# ...

# %% [markdown]
# # Ohsumed

# %%
df = pd.read_csv("real_data/train/ohsumedtrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)
df = pd.read_csv("real_data/test/ohsumedAll.csv")
print("Number of test samples: ", len(df))
# Out:
#    0                                                  1  \
# 0  1  Improved outcome at 28 days of age for very lo...
# 1  2  Chylothorax after posterior spinal instrumenta...
# 2  3  Childhood pulmonary function following hyaline...
# 3  4  Treatment of atelectasis of upper lung lobes. ...
# 4  5  Decision analysis, public health policy, and i...
#
#                             2
# 0  Respiratory Tract Diseases
# 1  Respiratory Tract Diseases
# 2  Respiratory Tract Diseases
# 3  Respiratory Tract Diseases
# 4  Respiratory Tract Diseases
# Number of train samples: 10433
# ...

# %% [markdown]
# # Reuters

# %%
df = pd.read_csv("real_data/train/reuterstrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/reutersAll.csv")
print("Number of test samples: ", len(df))
# Out:
#      0                                                  1         2
# 0  118    SEIPP SAYS GERMAN INTEREST RATES SHOULD FALL...  interest
# 1  119    U.K. MONEY DATA MAY EASE RATE CUT, ANALYSTS ...  interest
# 2  120    TREASURY BALANCES AT FED ROSE ON MARCH 23   ...  interest
# 3  121    BANK OF SPAIN SUSPENDS ASSISTANCE, DRAINS FU...  interest
# 4  122    FED SETS TWO BILLION DLR CUSTOMER REPURCHASE...  interest
# Number of train samples: 6800
# Set of labels: {'acq', 'money-fx', 'grain', 'crude', 'ship', 'interest', 'trade', 'earn'}
# Number of labels: 8
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    6800.00
# mean      133.27
# std       140.67
# min         7.00
# 25%        48.00
# 50%        87.00
# 75%       163.00
# max      1320.00
# Name: text_length, dtype: float64
# Number of test samples:  2659

# %% [markdown]
# # IMDB reviews

# %%
df = pd.read_csv("real_data/train/reviewstrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/reviewsAll.csv")
print("Number of test samples: ", len(df))
# Out:
#                         0                                                  1  \
# 0      0_0_train_addition  Story of a man who has unnatural feelings for ...
# 1      0_1_train_addition  Bromwell High is a cartoon comedy. It ran at t...
# 2  10000_0_train_addition  Airport '77 starts as a brand new luxury 747 p...
# 3  10000_1_train_addition  Homelessness (or Houselessness as George Carli...
# 4  10001_0_train_addition  This film lacked something I couldn't put my f...
#
#           2
# 0  negative
# 1  positive
# 2  negative
# 3  positive
# 4  negative
# Number of train samples: 28000
# Set of labels: {'positive', 'negative'}
# Number of labels: 2
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    28000.00
# mean       233.51
# std        173.16
# min         10.00
# 25%        127.00
# 50%        174.00
# 75%        285.00
# max       2470.00
# Name: text_length, dtype: float64
# ...

# %% [markdown]
# # SemEval 18 (Emoji)

# %%
df = pd.read_csv("real_data/train/semevalEmojitrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/semevalEmojiAll.csv")
print("Number of test samples: ", len(df))
# Out:
#          0                                                  1  \
# 0  1000000  Last stop @user before going back to Cali ️ #p...
# 1   500001  Sunday afternoon walking through Venice in the...
# 2   500002  Time for some BBQ and whiskey libations. Chomp...
# 3   500003  Love love love all these people ️ ️ ️ #friends...
# 4   500004                                ️ ️ ️ ️ @ Toys"R"Us
#
#                           2
# 0                       sun
# 1                       sun
# 2  winking face with tongue
# 3                 red heart
# 4                 red heart
# Number of train samples: 500000
# ...

# %% [markdown]
# # SemEval 18 (Irony)

# %%
df = pd.read_csv("real_data/train/semevalironytrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/semevalironyAll.csv")
print("Number of test samples: ", len(df))
# Out:
#    0                                                  1          2
# 0  0  seeing ppl walking w/ crutches makes me really...      irony
# 1  1  look for the girl with the broken smile, ask h...  non irony
# 2  2  Now I remember why I buy books online @user #s...      irony
# 3  3  @user @user So is he banded from wearing the c...      irony
# 4  4  Just found out there are Etch A Sketch apps.  ...      irony
# Number of train samples: 2862
# Set of labels: {'irony', 'non irony'}
# Number of labels: 2
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    2862.00
# mean       13.61
# std         6.69
# min         1.00
# 25%         9.00
# 50%        13.00
# 75%        18.00
# max       177.00
# Name: text_length, dtype: float64
# Number of test samples:  784

# %% [markdown]
# # SemEval 19 (Hateval)

# %%
df = pd.read_csv("real_data/train/semevalhatetrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/semevalhateAll.csv")
print("Number of test samples: ", len(df))
# Out:
#    0                                                  1         2
# 0  0  @user nice new signage. Are you not concerned ...  non-hate
# 1  1  A woman who you fucked multiple times saying y...      hate
# 2  2  @user @user real talk do you have eyes or were...      hate
# 3  3  your girlfriend lookin at me like a groupie in...      hate
# 4  4                        Hysterical woman like @user  non-hate
# Number of train samples: 9000
# Set of labels: {'hate', 'non-hate'}
# Number of labels: 2
# Missing Values:
# 0              0
# text           7
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    9000.00
# mean       20.82
# std        10.87
# min         1.00
# 25%        13.00
# 50%        19.00
# 75%        27.00
# max        63.00
# Name: text_length, dtype: float64
# Number of test samples:  2970

# %% [markdown]
# # SemEval 19 (OffensEval)

# %%
df = pd.read_csv("real_data/train/semevaloffensivetrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/semevaloffensiveAll.csv")
print("Number of test samples: ", len(df))
# Out:
#    0                                                  1              2
# 0  0  @user Bono... who cares. Soon people will unde...  non-offensive
# 1  1  @user Eight years the republicans denied obama...      offensive
# 2  2  @user Get him some line help. He is gonna be j...  non-offensive
# 3  3                @user @user She is great. Hi Fiona!  non-offensive
# 4  4  @user She has become a parody unto herself? Sh...      offensive
# Number of train samples: 11916
# Set of labels: {'non-offensive', 'offensive'}
# Number of labels: 2
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    11916.00
# mean        22.02
# std         15.05
# min          2.00
# 25%         10.00
# 50%         18.00
# 75%         32.00
# max        103.00
# Name: text_length, dtype: float64
# Number of test samples:  860

# %% [markdown]
# # SemEval 17 (Sentiment)

# %%
df = pd.read_csv("real_data/train/semevalSentimenttrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/semevalSentimentAll.csv")
print("Number of test samples: ", len(df))
# Out:
#    0                                                  1         2
# 0  0  "QT @user In the original draft of the 7th boo...  positive
# 1  1  "Ben Smith / Smith (concussion) remains out of...   neutral
# 2  2  Sorry bout the stream last night I crashed out...   neutral
# 3  3  Chase Headley's RBI double in the 8th inning o...   neutral
# 4  4  @user Alciato: Bee will invest 150 million in ...  positive
# Number of train samples: 45615
# Set of labels: {'positive', 'negative', 'neutral'}
# Number of labels: 3
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    45615.00
# mean        19.24
# std          4.94
# min          1.00
# 25%         16.00
# 50%         20.00
# 75%         23.00
# max         35.00
# Name: text_length, dtype: float64
# Number of test samples:  12284

# %% [markdown]
# # Toxic Comments

# %%
df = pd.read_csv("real_data/train/toxictrainAll.csv")
display(df.head())
df = df.rename(columns={"1": "text", "2": "label"})
basic_analysis(df)

df = pd.read_csv("real_data/test/toxicAll.csv")
print("Number of test samples: ", len(df))
# Out:
#                   0                                                  1  \
# 0  0000997932d777bf  ExplanationWhy the edits made under my usernam...
# 1  000103f0d9cfb60f  D'aww! He matches this background colour I'm s...
# 2  000113f07ec002fd  Hey man, I'm really not trying to edit war. It...
# 3  0001b41b1c6bb37e  MoreI can't make any real suggestions on impro...
# 4  0001d958c54c6e35  You, sir, are my hero. Any chance you remember...
#
#                2
# 0  ['non-toxic']
# 1  ['non-toxic']
# 2  ['non-toxic']
# 3  ['non-toxic']
# 4  ['non-toxic']
# Number of train samples: 149706
# Set of labels: {"['non-toxic']", "['threat']", "['identity hate']", "['obscene']", "['insult']", "['toxic']"}
# Number of labels: 6
# Missing Values:
# 0              0
# text           0
# label          0
# text_length    0
# dtype: int64
#
# Word Count Statistics:
# count    149706.00
# mean         67.29
# std          97.11
# min           1.00
# 25%          17.00
# 50%          36.00
# ...
